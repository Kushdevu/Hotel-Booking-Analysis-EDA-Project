# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushdevu/Hotel-Booking-Analysis-EDA-Project/blob/main/Copy_of_Sample_EDA_Submission_Template_ipynb0008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -  **Hotel Booking Analysis Exploratory Data Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ##### The hotel booking dataset provides a comprehensive and anonymized view of booking information for both city and resort hotels, allowing for in-depth analysis and insights into the factors that influence hotel bookings. The dataset includes a wide range of columns, covering details such as booking timing, length of stay, guest demographics, special requests, and more.
#
# Key columns in the dataset include information on whether a booking was canceled, the lead time between booking and arrival, the type of meal included, the guest's country of origin, and various booking characteristics like room type, deposit type, and more. Additionally, the dataset offers insights into the hotel's occupancy, pricing, and revenue management strategies.
#
# Analysis of this dataset can provide valuable insights for businesses in the hospitality industry.
#
# In summary, this hotel booking dataset serves as a valuable resource for businesses and analysts in the hospitality industry. It enables data-driven decision-making by providing insights into booking trends, customer behavior, and operational aspects of hotel management. By analyzing this data, businesses can enhance revenue management, improve customer satisfaction, and optimize their overall operations.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Kushdevu/Hotel-Booking-Analysis-EDA-Project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **In today's competitive hotel industry, optimizing booking strategies and guest experiences is crucial for hotel owners and managers to maximize revenue and customer satisfaction. To address these challenges, we aim to analyze a comprehensive hotel booking dataset and extract actionable insights that can inform data-driven decision-making in the hotel business.**
#
# We will commence with data cleaning and preprocessing to address missing values, duplicates, and create relevant derived features. Subsequently, we will conduct exploratory data analysis (EDA) to glean insights into the dataset and visualize relationships between variables.
#
# We will employ various statistical analysis techniques, data visualization tools to fulfill our objectives. This may entail regression models for cancellation prediction, clustering for customer segmentation, and other suitable methods for different aspects of the analysis.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **The primary business objective is to maximize the profitability and competitiveness of a hotel or hotel chain through data-driven decision-making and strategic optimization. This objective encompasses various facets of hotel management, revenue generation, and guest satisfaction.**
#
# **Key Components of the Business Objective:**
# Revenue Maximization, Occupancy Optimization, Cancellation Reduction, Customer Satisfaction, Cost Management, Market Segmentation, Competitive Advantage, Data-Driven Decision-Making, Agent and Company Relationships, Waiting List Effectiveness.
#
# **Measurement and Success Criteria:**
#
# The success of achieving the business objective will be measured using key performance indicators (KPIs) and benchmarks, including:
#
# Revenue Metrics, Occupancy Rates, Cancellation Rates, Customer Satisfaction Scores, Cost Control, Market Share, Competitive Analysis, Data Utilization,Agent and Company Performance, Waiting List Conversion.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
file_path = "/content/drive/MyDrive/Colab Notebooks/Module 2/Capstone Project 2/Hotel Bookings.csv"
df = pd.read_csv(file_path )

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
df.shape
# Out:
# (119390, 32)

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
duplicate_count
# Out:
# 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Missing Values/Null Values Count
df.isna().sum().sort_values(ascending=False)[:4]
# Out:
# company     112593
# agent        16340
# country        488
# children         4
# dtype: int64

# %%
# Visualizing the missing values
missing_values_count = df.isna().sum()
# Create a bar plot to visualize missing values
plt.figure(figsize=(10, 6))
sns.barplot(x=missing_values_count.index, y=missing_values_count.values, palette='rocket')
plt.xlabel('Columns')
plt.ylabel('Count of Missing Values')
plt.title('Missing Values in Dataset')
plt.xticks(rotation=90)  # Rotate x-axis labels for better visibility
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer
#
# Dataset Shape: The dataset has a shape of (119,390, 32), meaning it contains 119,390 rows and 32 columns.
#
# Data Types: The dataset contains columns with various data types, including integers (int64), floating-point numbers (float64), and objects (strings).
#
# Missing Values: Some columns have missing values:
#
# 'company' has a large number of missing values (82,137).
#
# 'agent' has some missing values (12,193).
#
# 'country' has a few missing values (452).
#
# 'children' has a small number of missing values (4).
#
# Duplicated Rows: The dataset initially contained duplicated rows (31,994 duplicates), but removed them, resulting in a dataset with 87,396 rows.
#
# Columns: There are 32 columns in the dataset, and each column has a specific meaning. Some of the important columns include:
#
# hotel: The name of the hotel.
# is_canceled: Indicates whether a booking was canceled (1) or not (0).
#
# lead_time: The number of days between booking and arrival.
#
# arrival_date_year: The year of arrival.
#
# arrival_date_month: The month of arrival.
#
# adults, children, babies: The number of adults, children, and babies in the booking.
#
# meal: The type of meal booked.
#
# country: The country of origin of the guests.
#
# market_segment: The market segment designation
# .
# distribution_channel: The distribution channel used to book the reservation.
#
# is_repeated_guest: Indicates whether the guest is a repeated guest (1) or not (0).
#
# previous_cancellations: The number of previous cancellations by the guest.
#
# previous_bookings_not_canceled: The number of previous bookings not canceled by the guest.
#
# reserved_room_type: The type of room reserved.
#
# assigned_room_type: The type of room assigned.
#
# booking_changes: The number of changes made to the booking.
#
# deposit_type: The type of deposit made for the reservation.
#
# agent: The ID of the booking agent.
#
# company: The ID of the company making the booking.
#
# customer_type: The type of customer (e.g., transient, contract).
#
# adr: Average Daily Rate, i.e., the average price per night.
#
# required_car_parking_spaces: The number of car parking spaces required.
#
# total_of_special_requests: The total number of special requests made by the guest.
#
# reservation_status: The reservation status (e.g., checked-in, canceled).
#
# reservation_status_date: The date when the reservation status was last updated.
#
# Memory Usage: The dataset consumes approximately 29.1 MB of memory.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer
#
# hotel: This variable represents the type of hotel the reservation was made for, with two unique values: "City Hotel" and "Resort Hotel".
#
# is_canceled: This is a binary variable indicating whether the reservation was canceled (1) or not (0).
#
# lead_time: It represents the number of days between the booking date and the arrival date.
#
# arrival_date_year: The year of the arrival date.
#
# arrival_date_month: The month of the arrival date.
#
# arrival_date_week_number: The week number of the arrival date.
#
# arrival_date_day_of_month: The day of the month of the arrival date.
#
# stays_in_weekend_nights: The number of weekend nights (Saturday and Sunday) the guest stayed.
#
# stays_in_week_nights: The number of weekday nights (Monday to Friday) the guest stayed.
#
# adults: The number of adults included in the reservation.
#
# children: The number of children included in the reservation.
#
# babies: The number of babies included in the reservation.
#
# meal: The type of meal included in the reservation.
#
# country: The country of origin of the guest.
#
# market_segment: The market segment designation, which could represent how the booking was made.
#
# distribution_channel: The distribution channel through which the reservation was made.
#
# is_repeated_guest: Indicates whether the guest is a repeated guest (1) or not (0).
#
# previous_cancellations: The number of previous cancellations made by the guest.
#
# previous_bookings_not_canceled: The number of previous bookings that were not canceled by the guest.
#
# reserved_room_type: The type of room reserved.
#
# assigned_room_type: The type of room assigned to the guest upon arrival.
#
# booking_changes: The number of changes made to the booking.
#
# deposit_type: The type of deposit made for the reservation.
#
# agent: The ID of the travel agency that made the reservation.
#
# company: The ID of the company that made the reservation.
#
# days_in_waiting_list: The number of days the booking was on the waiting list before it was confirmed.
#
# customer_type: The type of customer, which may represent the nature of the booking.
#
# adr: The average daily rate (price) for the reservation.
#
# required_car_parking_spaces: The number of car parking spaces required by the guest.
#
# total_of_special_requests: The total number of special requests made by the guest.
#
# reservation_status: The reservation status.
#
# reservation_status_date: The date on which the reservation status was last updated.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
    print(f"Unique values for {column}:")
    print(df[column].unique())
    print()
# Out:
# Unique values for hotel:
# ['Resort Hotel' 'City Hotel']
#
# Unique values for is_canceled:
# [0 1]
#
# Unique values for lead_time:
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Handling Duplicates
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (87396, 32)

# %%
#Handling Missing Values
#Imputing Null values with appropriate measures
df['company'].fillna(df['company'].astype('float').mean(), inplace=True)
df['country'].fillna(df['country'].mode().to_string(), inplace=True)
df['agent'].fillna(0, inplace=True)
df['agent'] = df['agent'].round()
df['children'].fillna(0, inplace=True)

# %%
df.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# ### **Adding some columns.**

# %%
#Adding total stay column in dataframe that is (stays_in_week_nights + stays_in_weekend_nights)
df['total_stay'] = df['stays_in_week_nights']+df['stays_in_weekend_nights']

#Adding total people columns that is(adults + children + babies)
df['total_people'] = df['adults'] + df['children'] + df['babies']

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...     company  \
# 0                        0                     0       2  ...  183.081384
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer
#
# Data Manipulations:
#
# Handling Missing Values:
#
# Identified missing values in the columns company, agent, country, and children.
#
# Filled missing values in the company column with the mean value of that column.
#
# Filled missing values in the country column with the mode (most frequent) value of that column.
#
# Filled missing values in the agent column fill with (0) value of that column.
#
# Filled missing values in the children column fill with (0) value of that column.
#
# Handling Duplicates:
#
# Identified and dropped duplicate rows in the dataset, resulting in a reduced dataset with 87,396 rows.
#
# Feature Engineering:
#
# Added two new columns to the dataset:
# 'total_stay': The sum of 'stays_in_week_nights' and 'stays_in_weekend_nights'.
#
# 'total_people': The sum of 'adults', 'children', and 'babies'.
#
# Data Exploration:
# Provided summary statistics for numeric columns, including mean, standard deviation, minimum, 25th percentile, median (50th percentile), 75th percentile, and maximum values.
#
# Column Information:
# Listed the column names and their data types in the dataset.
#
# Basic Data Overview:
# Shared the shape of the dataset, including the number of rows and columns.
# Mentioned the presence of missing values and the number of duplicated rows in the original dataset.
#
# Insights:
#
# Data Types:
#
# Provided information about the data types of each column in the dataset, including object (categorical), int64 (integer), and float64 (floating-point).
#
# Summary Statistics:
#
# Presented summary statistics for numeric columns, including count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum values for various attributes such as lead time, number of adults, children, babies, and others.
#
# Overview of Columns:
#
# Listed the column names and provided a brief description of their meanings, such as the hotel type, booking status, booking lead time, and more.
#
# Categorical Columns:
#
# Identified several categorical columns, including hotel, arrival_date_month, meal, country, market_segment, distribution_channel, reserved_room_type, assigned_room_type, deposit_type, customer_type, reservation_status, and reservation_status_date.
#
# Overall, data cleaning was performed by addressing missing values and duplicates, and some basic insights into the dataset's structure and content were provided. However, for more in-depth analysis, further exploration and visualization of the data may be required, such as exploring correlations between variables or building predictive models based on the dataset.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1
#
# ##### Q1. which type of hotels are most preferred by customer ?

# %%
df['hotel'].value_counts()
# Out:
# City Hotel      53428
# Resort Hotel    33968
# Name: hotel, dtype: int64

# %%
# Chart - 1 visualization code
plt.figure(figsize=(5, 5))
plt.pie(df['hotel'].value_counts(), labels=df['hotel'].value_counts().keys(), autopct='%0.1f%%')
plt.title('Percentage of Most Preferred Hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# * Pie chart for this specific data because it is a suitable choice given the limited number of categories and the desire to provide a quick and clear understanding of the distribution of hotel preferences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# * Here, we found that the booking number is Higher in City Hotel which is 61.12% than Resort Hotel which is 38.87%. Hence we can say that City hotel has more consumption
#
# *   City hotels are more preferred by guest as city hotels are mostly near by Airports, Railway stations
# * Resort are situated at longer distance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact:**
#
# Catering to Customer Preferences: Understanding that City Hotels are more preferred by customers suggests that investing in or expanding City Hotel offerings could lead to increased bookings and revenue. This aligns with customer preferences, potentially resulting in positive growth for the business.
#
# **Negative Growth Considerations:**
#
# Ignoring Customer Feedback: If the business fails to pay attention to customer feedback and preferences, it may miss opportunities to improve both types of hotels. For instance, if customers complain about the lack of certain amenities at Resort Hotels, ignoring these concerns could lead to declining bookings and negative reviews.

# %% [markdown]
# #### Chart - 2
#
# ##### Q2. Which year has the highest bookings?

# %%
#check which year has highest bookings
df['arrival_date_year'].value_counts()
# Out:
# 2016    42391
# 2017    31692
# 2015    13313
# Name: arrival_date_year, dtype: int64

# %%
# Chart - 2 visualization code
plt.figure(figsize=(5,5))
sns.countplot(x=df['arrival_date_year'],hue=df['hotel'],palette='rocket')
plt.xlabel('Arrival date year')
plt.ylabel('Number of bookings')
plt.title('Number of bookings in different year')
# Out:
# Text(0.5, 1.0, 'Number of bookings in different year')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# The choice of a grouped bar chart is appropriate for visually presenting and comparing the number of bookings across different years while distinguishing between City Hotel and Resort Hotel bookings within each year. It effectively conveys this information in a clear and comprehensible manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   Year 2016 has the highest number of bookings (42391) followed by 2017  (31692) and 2015 (13313). It means 2016 and 2017 was a very good year for hotel industry and In 2016 and 2017 more booking was in city hotels and in 2015 it is slighlty lower than resort hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact:**
#
# Optimizing for Peak Years: Recognizing that 2016 and 2017 were particularly good years for the hotel industry, the business can use this information to plan for peak periods in the future. This might involve allocating more resources, marketing efforts, and staff during these years to maximize revenue.
#
# **Negative Growth Considerations:**
#
# Resort Hotel Preferences in 2015: The data shows that in 2015, Resort Hotels had slightly more bookings than City Hotels. Neglecting the preferences of customers for Resort Hotels during that year could lead to missed revenue opportunities. The business should consider strategies to maintain a balance between both hotel types, ensuring that both are appealing to guests in different years.

# %% [markdown]
# #### Chart - 3
#
# ##### Q3. Which meal type is most preffered meal of customers ?

# %%
# Chart - 3 visualization code
plt.figure( figsize=(10, 8))

sns.countplot(x = df['meal'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# Countplot, which is essentially a bar chart used to visualize the frequency or count of categories within a categorical variable.Countplot is a suitable choice for visually presenting and comparing the frequency of different meal types preferred by customers, as it effectively conveys this information in a clear and visually accessible manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# Types of meal in hotels:
# * BB - (Bed and Breakfast)
# * HB- (Half Board)
# * FB- (Full Board)
# * SC- (Self Catering)
#
# **insight(s)**
#
# * Most preferred meal type by the guest is BB (Bed and Breakfast).
# * SC and HB are equally preferred, undefined and Fb are very less.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact:**
#
# Catering to Guest Preferences: Recognizing that BB (Bed and Breakfast) is the most preferred meal type, the business can focus on enhancing breakfast offerings, ensuring a satisfying and high-quality breakfast experience for guests. This can lead to positive guest reviews and increased customer satisfaction.
#
# **Negative Growth Considerations:**
#
# Undefined Meal Types: The presence of undefined meal types may indicate data quality issues or incomplete records. This could lead to confusion for guests and staff, potentially resulting in negative guest experiences. It's important for the business to clarify and address these undefined meal types.

# %% [markdown]
# #### Chart - 4
#
# ##### 1. The top 5 countries with the highest number of bookings in a dataset ?

# %%
# Chart - 4 visualization code
top_5_countries = df['country'].value_counts().head(5)
top_5_countries.plot(kind = 'bar',color = '#00b09b',figsize=(8,5))
plt.title("Top 5 countries", weight ='bold')
plt.xlabel("Country", weight='bold')
plt.ylabel('Number of Bookings', weight='bold')
# Out:
# Text(0, 0.5, 'Number of Bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# The choice of a bar chart for visualizing the top 5 countries with the highest number of bookings is appropriate because it aligns with best practices for presenting and comparing categorical data effectively and clearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# Abbreviation for countries-
#
# PRT- Portugal,
# GBR- United Kingdom,
# FRA- France,
# ESP- Spain,
# DEU - Germany,
# ITA -Itlay,
# IRL - Ireland,
# BEL -Belgium,
# BRA -Brazil,
# NLD-Netherlands
#
# **insight(s)**
#
# *  ***PRT (Portugal)*** is the top country in terms of number of bookings.
#
# *   Most number of guests are coming from portugal more than 27000 may be the hotels are situated in Portugal.
#
# *   GBR (UK) and FRA (France) are approximately (1/5)th of the Portugal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact Considerations:**
#
# Targeted Marketing: Given that Portugal is the top source of guests, the hotel can consider targeted marketing efforts in Portugal to maintain and potentially grow its customer base from this region. Understanding the preferences and needs of Portuguese guests can lead to positive guest experiences and repeat bookings.
#
# Regional Expansion: If the hotel's primary location is in Portugal, it may consider expanding its reach to accommodate the high demand from this region. This could involve opening more branches or increasing capacity.
#
# **Negative Growth Considerations:**
#
# Dependency on a Single Region: While Portugal may be the top source of bookings, it's important not to become overly dependent on a single region. Overreliance on one market can be risky, as economic or geopolitical factors could impact travel patterns from that region.
#
# Market Saturation: The data shows that the United Kingdom and France also contribute significantly to bookings, but they are not growing at the same rate as Portugal. If the hotel heavily invests in these markets without considering the potential for market saturation, it may not yield significant growth.

# %% [markdown]
# #### Chart - 5
#
# ##### Q5. Which agent has made most bookings?

# %%
#booking made by agents
booking_agents = df['agent'].value_counts().reset_index().rename(columns ={'index':'agent','agent':'Most_bookings'})

#top 10 booking agents
top_10_agents = booking_agents[:10]
top_10_agents
# Out:
#    agent  Most_bookings
# 0    9.0          28759
# 1  240.0          13028
# 2    0.0          12193
# 3   14.0           3349
# 4    7.0           3300
# 5  250.0           2779
# 6  241.0           1644
# 7   28.0           1502
# 8    8.0           1383
# 9    1.0           1232

# %%
# Chart - 5 visualization code
#Visualize top 10 agents who made hotel bookings
plt.figure(figsize=(12,6))
sns.barplot(x = top_10_agents['agent'], y = top_10_agents['Most_bookings'],order = top_10_agents['agent'],palette='rocket')
plt.xlabel('Agent Number')
plt.ylabel('Number of Bookings')
plt.title('Bookings made by agent')
# Out:
# Text(0.5, 1.0, 'Bookings made by agent')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# The selection of a bar chart for visualizing the number of bookings made by the top 10 agents aligns with best practices for presenting and comparing categorical data effectively and clearly. It is a well-suited choice for this type of analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   Id Number 9 agent has made most numbers of bookings 28759.
# * Id Number 240 has most number of bookings after ID 94 followed by 14 and 7.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact Considerations:**
#
# Recognizing Top Performers: Identifying and recognizing the top-performing agent (ID 9) is essential. The hotel can acknowledge the agent's efforts and potentially provide incentives or rewards to encourage continued high performance.
#
# Optimizing Resources: By understanding which agents are responsible for a significant portion of bookings, the hotel can allocate resources effectively. This may involve assigning dedicated support or services to handle bookings from top-performing agents, ensuring a positive guest experience.
#
# **Negative Growth Considerations:**
#
# Dependency on Individual Agents: While recognizing top performers is positive, the hotel should avoid overdependency on a single agent or a small number of agents. Relying too heavily on one individual can be risky, as their performance may fluctuate or they may leave the organization.

# %% [markdown]
# #### Chart - 6
#
# ##### Q6. What is the percentage of booking cancellation?

# %%
#check how many bookings were cancelled
df['is_canceled'].value_counts()
# Out:
# 0    63371
# 1    24025
# Name: is_canceled, dtype: int64

# %%
# Chart - 6 visualization code
plt.figure(figsize=(5,5))
plt.pie(df['is_canceled'].value_counts(),labels=df['is_canceled'].value_counts().keys(),autopct = '%0.1f%%')
plt.title('Percentage of Hotel booking Cancellation vs Non concellation')
# Out:
# Text(0.5, 1.0, 'Percentage of Hotel booking Cancellation vs Non concellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# The choice of a pie chart for visualizing the percentage distribution of hotel booking cancellations versus non-cancellations aligns with best practices for presenting this type of data when there are only two categories to compare. It offers a clear and visually engaging representation of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   0 means not cancelled and 1 is cancelled.
# *   27.5 % bookings were cancelled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact Considerations:**
#
# Understanding Cancellation Rate: Understanding the cancellation rate is essential for managing hotel operations effectively. It provides insights into the proportion of bookings that do not result in a stay, which can inform revenue management and resource allocation.
#
# Cancellation Policies: The insights can inform the hotel's cancellation policies. It can consider adjusting cancellation deadlines and fees to minimize cancellations or encourage direct bookings.
#
# **Negative Growth Considerations:**
#
# Impact on Revenue: High cancellation rates can have a negative impact on revenue, as cancelled bookings result in unoccupied rooms. If the cancellation rate remains consistently high, it may lead to reduced revenue and profitability.
#
# Resource Allocation: Managing a high cancellation rate may require additional resources for handling cancellations, processing refunds, and addressing guest inquiries. This can increase operational costs.

# %% [markdown]
# #### Chart - 7
#
# ##### Q7. Does longer waiting period causes booking cancellation?

# %%
#create data frame where days of waiting is more than zero
waiting_list = df[df['days_in_waiting_list']!=0]
waiting_list.head()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 2272  Resort Hotel            0         59               2015
# 2486  Resort Hotel            0         47               2015
# 2508  Resort Hotel            0         47               2015
# 3106  Resort Hotel            0        105               2015
# 3118  Resort Hotel            0        105               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 2272            October                        41                          8
# 2486            October                        43                         19
# 2508            October                        43                         19
# 3106           November                        47                         18
# 3118           November                        47                         18
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  ...     company  \
# ...

# %%
# Chart - 7 visualization code
plt.figure(figsize=(12,8))
sns.kdeplot(x='days_in_waiting_list',hue='is_canceled',data=waiting_list)
plt.title('Effect of days in waiting list on booking cancellation')
# Out:
# Text(0.5, 1.0, 'Effect of days in waiting list on booking cancellation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# The choice of a KDE plot for visualizing the effect of waiting list duration on booking cancellations is appropriate because it effectively presents the distribution of continuous data and allows for the comparison of two important groups, providing insights into the relationship between waiting time and cancellations.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   We can see that most bookings were cancelled which has less than 100 days in waiting list but also bookings were not cancelled for the same still density of cancelled is slightly higher for the same but there is no direct effect of longer waiting period with booking cancellation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact Considerations:**
#
# Optimizing Policies: The insights can help the hotel in optimizing its policies and procedures related to waiting lists. This could involve improving communication with guests during waiting, managing overbookings, or refining cancellation policies.
#
# Resource Allocation: The hotel can allocate resources effectively based on the observed cancellation patterns. For instance, if cancellations are concentrated in the early waiting period, the hotel can focus on optimizing room availability and communication during that period.
#
# **Negative Growth Considerations:**
#
# Guest Experience: While longer waiting times do not necessarily result in more cancellations, lengthy waiting times can still lead to guest dissatisfaction. Negative guest experiences can affect repeat business and online reviews, potentially leading to negative growth.
#
# Revenue Impact: If cancellations are more common for bookings with shorter waiting times, it can still have a revenue impact due to unoccupied rooms. The hotel should aim to minimize cancellations and optimize room inventory.

# %% [markdown]
# #### Chart - 8
#
# ##### Q8. Which month has the highest number of bookings overall?

# %%
#check month wise bookings
df['arrival_date_month'].value_counts()
# Out:
# August       11257
# July         10057
# May           8355
# April         7908
# June          7765
# March         7513
# October       6934
# September     6690
# February      6098
# December      5131
# November      4995
# January       4693
# Name: arrival_date_month, dtype: int64

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10,5))
sns.lineplot(x=df['arrival_date_month'].value_counts().keys(),y=df['arrival_date_month'].value_counts())
sns.barplot(x=df['arrival_date_month'].value_counts().keys(),y=df['arrival_date_month'].value_counts())
plt.xticks(rotation=45)
plt.xlabel('Arrival month')
plt.ylabel('Number of bookings')
plt.title('Month wise hotel bookings')
# Out:
# Text(0.5, 1.0, 'Month wise hotel bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# The choice of combining a line plot and a bar plot in a single chart depends on the specific goals of the visualization and the intended audience. While it can offer a comprehensive view of the data, it's important to consider potential complexities and ensure that the chart remains clear and informative.
#
# The specific chart was chosen to provide a comprehensive view of month-wise hotel bookings, allowing viewers to analyze trends and counts simultaneously. It's designed to facilitate a deeper understanding of booking patterns throughout the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   It seems that august has the highest number of bookings followed by july and may and least bookings are in november and january.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact Considerations:**
#
# Pricing Strategies: During peak months, the hotel can implement pricing strategies to maximize revenue. Higher demand periods may allow for slightly higher room rates, potentially increasing profitability.
#
# Marketing Focus: The hotel can focus its marketing efforts and promotions during the months with lower bookings (such as November and January) to attract more guests during off-peak periods. Special offers or promotions can be designed to incentivize bookings during these times.
#
# **Negative Growth Considerations:**
#
# Resource Management: The hotel must carefully manage its resources during peak months to avoid overextension and maintain high-quality services. Overcommitting resources may lead to increased costs without a corresponding increase in revenue.

# %% [markdown]
# #### Chart - 9
#
# ##### Q9. Which date day of month has the highest number of booking overall?

# %%
#check date day of months wise booking
df['arrival_date_day_of_month'].value_counts()
# Out:
# 17    3020
# 2     3016
# 26    3000
# 5     2980
# 16    2959
# 19    2949
# 12    2929
# 28    2929
# 18    2924
# 11    2915
# 20    2915
# 27    2902
# 29    2880
# 9     2878
# 15    2869
# 25    2838
# 3     2834
# 21    2823
# 13    2812
# 8     2809
# 6     2805
# 4     2801
# 10    2785
# 23    2776
# 24    2775
# 30    2772
# 1     2770
# 7     2704
# 14    2693
# 22    2601
# 31    1733
# Name: arrival_date_day_of_month, dtype: int64

# %%
# Chart - 9 visualization code
plt.figure(figsize=(18,8))
sns.barplot(x=df['arrival_date_day_of_month'].value_counts().keys(),y=df['arrival_date_day_of_month'].value_counts())
plt.xlabel('Date day of month')
plt.ylabel('Count')
plt.title('Date day of months with highest bookings')
# Out:
# Text(0.5, 1.0, 'Date day of months with highest bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# The selection of a bar plot for this specific data visualization task aligns with best practices for presenting and comparing categorical data effectively, making it a suitable choice for visualizing the distribution of bookings across days of the month.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   We can see that the bookings are equally distributed amongs date day of month and only less numbers of bookings are on date 31.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact Considerations:**
#
# Optimizing Resources: If the distribution of bookings across days of the month remains consistent and balanced, it can help the hotel business allocate resources more evenly. This includes staffing, room preparation, and inventory management. By maintaining a steady level of service quality throughout the month, customer satisfaction can be improved.
#
# Pricing Strategies: The consistent distribution of bookings may allow the business to develop pricing strategies that optimize revenue throughout the month, rather than relying heavily on peak days. This can lead to a more stable and sustainable revenue stream.
#
# **Negative Growth Considerations:**
#
# Underutilization of Resources: While a balanced distribution of bookings can optimize resource allocation, it can also lead to the underutilization of resources during certain periods. If the hotel staff and facilities are consistently prepared for higher demand but the actual bookings remain evenly distributed, it may result in higher operational costs and lower profitability.

# %% [markdown]
# #### Chart - 10
#
# ##### Q10. What is the percentage distribution of customer type?

# %%
#check distribution of customer type
df['customer_type'].value_counts()
# Out:
# Transient          71986
# Transient-Party    11727
# Contract            3139
# Group                544
# Name: customer_type, dtype: int64

# %%
# Chart - 10 visualization code
plt.figure(figsize=(6,6))
plt.pie(df['customer_type'].value_counts(),labels=None,autopct='%0.1f%%')
plt.title('Distribution Percentage of customer type')
legend = list(df['customer_type'].value_counts().keys())
plt.legend(legend,loc='upper left')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# Pie chart is commonly chosen for displaying the distribution percentage of categories, such as customer types, when the number of categories is limited and when the goal is to provide a clear and intuitive representation of the data. choice of a pie chart effectively communicates the distribution of customer types in a visually accessible manner.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   **Contract**:
# when the booking has an allotment or other type of contract associated to it.
# * **Group**:
# when the booking is associated to a group.
# * **Transient**:
# when the booking is not part of a group or contract,amongs non-group category are transient.
# * **Transient-party**:
# when the booking is transient, but it is associated to at least other transient booking.
#
# **Insight**
#
# *   Transient has the highest distribution percentage of customer type (82.4%) and least 0.6% associated with Group customer type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Asnwer
#
# **Positive Business Impact:**
#
# Targeting Transient Customers: Since "Transient" customers constitute the majority of bookings, the business can tailor its marketing efforts and services to cater to this customer segment. Understanding the preferences and needs of transient guests can lead to positive guest experiences and potential repeat bookings.
#
# **Negative Growth Considerations:**
#
# Group Customer Type: While the "Group" customer type has a low distribution percentage, it's crucial not to overlook this segment. Depending on the capacity and facilities of the hotel, accommodating groups can be financially rewarding, especially for large events, conferences, or tours. Neglecting the needs of group bookings may lead to missed revenue opportunities.

# %% [markdown]
# #### Chart - 11
#
# ##### Q11. Which is the most reserved room type by customer?

# %%
#Check room type reserved by customer
df['reserved_room_type'].value_counts()
# Out:
# A    56552
# D    17398
# E     6049
# F     2823
# G     2052
# B      999
# C      915
# H      596
# L        6
# P        6
# Name: reserved_room_type, dtype: int64

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10,5))
sns.barplot(x=df['reserved_room_type'].value_counts().keys(),y=df['reserved_room_type'].value_counts(),palette='rocket')
plt.xlabel('Room type')
plt.ylabel('Count')
plt.title('Reserved room type by customer')
# Out:
# Text(0.5, 1.0, 'Reserved room type by customer')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
#  Bar chart is a suitable choice for visualizing the distribution of reserved room types because it is specifically designed for categorical data and facilitates straightforward comparisons, making it easy to identify the most reserved room type by customers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   Most reserved room type is A.
# *   Least preferred are L and P.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact:**
#
# Pricing Strategy: The hotel can use this insight to adjust pricing strategies. Room type 'A' may command higher prices due to its popularity, while room types 'L' and 'P' could be priced more competitively to attract more bookings.
#
# Marketing Focus: The hotel can focus its marketing efforts on promoting room type 'A' to potential customers, emphasizing its features and benefits to further increase its popularity.
#
# **Negative Growth Potential:**
#
# Room Availability: If the hotel focuses solely on room type 'A' based on its popularity, it may face availability issues during peak booking periods for this specific room type. This could lead to missed revenue opportunities and customer dissatisfaction.

# %% [markdown]
# #### Chart - 12
#
# ##### Q12. Which distribution channel is mostly used for hotel bookings?

# %%
#check distribution channel
dcf =df['distribution_channel'].value_counts().reset_index().rename(columns={'index':"distribution_channel",'distribution_channel':'count'})
#add percenatge columns in dcf dataframe
dcf['percentage'] = round(dcf['count']*100/df.shape[0],1)
#Creating list of percentage
sizes=dcf['percentage'].values.tolist()

# %%
# Chart - 12 visualization code
plt.figure(figsize=(5,5))
plt.pie(df['distribution_channel'].value_counts(),labels=None)

#setting legends with percentage values
labels = df['distribution_channel'].value_counts().keys()
labels = [f'{l}, {s}%' for l, s in zip(labels, sizes)]
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

plt.title('Distribution channel which is mostly used for hotel bookings')
# Out:
# Text(0.5, 1.0, 'Distribution channel which is mostly used for hotel bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# Pie charts are commonly used to represent the distribution or composition of a categorical dataset where each category's value is expressed as a proportion of the whole. In this case, are using a pie chart to visualize the distribution of hotel bookings by different distribution channels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   TA/TO is mostly used for booking hotels followed by Direct.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact:**
#
# Optimizing Marketing Strategies: Knowing that "TA/TO" is the most popular distribution channel for hotel bookings, a hotel business can focus its marketing efforts and resources on building strong partnerships with travel agents and tour operators. This can lead to increased bookings and revenue through this channel.
#
# Direct Booking Promotion: Recognizing that "Direct" bookings also have a significant share, a hotel can implement strategies to encourage more direct bookings through its website or other direct booking channels. Offering incentives, discounts, or exclusive deals for direct bookings can help reduce reliance on third-party channels and increase profit margins.
#
# **Negative Growth Potential:**
#
# Overreliance on a Single Channel: While "TA/TO" is the dominant channel, overreliance on it could be risky. If a hotel becomes too dependent on a single channel and it experiences a decline in bookings or changes in business practices, the hotel could face negative growth. Diversification of distribution channels may be necessary to mitigate this risk.
#
# Neglecting Smaller Channels: Ignoring the smaller channels like "GDS" and "Undefined" entirely may result in missed opportunities. These channels, although representing a smaller share, could still bring in valuable bookings. Neglecting them entirely could limit potential growth.

# %% [markdown]
# #### Chart - 13
#
# ##### Q13. Which distribution channel has contributed more to adr in order to increase the revenue?

# %%
# group by distribution channel and hotel
dcf=df.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()
dcf
# Out:
#   distribution_channel         hotel         adr
# 0            Corporate    City Hotel   83.265884
# 1            Corporate  Resort Hotel   52.972522
# 2               Direct    City Hotel  112.092246
# 3               Direct  Resort Hotel  106.523946
# 4                  GDS    City Hotel  120.317845
# 5                TA/TO    City Hotel  112.426347
# 6                TA/TO  Resort Hotel  101.553533
# 7            Undefined    City Hotel   29.625000
# 8            Undefined  Resort Hotel  112.700000

# %%
# Chart - 13 visualization code
plt.figure(figsize=(12,8))
sns.barplot(x='distribution_channel', y='adr', data=dcf, hue='hotel',palette='mako')
plt.title('ADR across distribution channel')
# Out:
# Text(0.5, 1.0, 'ADR across distribution channel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# The barplot with hue-based differentiation is a suitable choice for comparing ADR across distribution channels and differentiating ADR values by hotel type within each distribution channel. It allows you to make clear visual comparisons and draw insights from the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   Corporate- These are corporate hotel booking companies which makes bookings possible.
# *   GDS-GDS is a worldwide conduit between travel bookers and suppliers, such as hotels and other accommodation providers. It communicates live product, price and availability data to travel agents and online booking engines, and allows for automated transactions.
# *  Direct- means that bookings are directly made with the respective hotels.
# *  TA/TO- means that booings are made through travel agents or travel operators.
# Undefined- Bookings are undefined. may be customers made their bookings on arrival.
#
#
#
#
#
# **insight(s)**
#
# *  'Direct' and 'TA/TO' has almost equally contributed in adr in both type of hotels.
# *   GDS has highly contributed in adr in 'City Hotel' type.
# * GDS contrbuting 0 in resort hotel bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Business Impact:**
#
# Optimizing 'Direct' and 'TA/TO' Channels: Since 'Direct' and 'TA/TO' channels are contributing significantly to ADR in both hotel types, the business can focus on strategies to further enhance bookings through these channels. This could include improving the hotel's online booking process, offering promotions to attract direct bookings, and building strong relationships with travel agents and operators for 'TA/TO' bookings.
#
# Leveraging GDS for City Hotels: The insight that GDS contributes significantly to ADR in 'City Hotel' type suggests that the business can continue to invest in GDS partnerships and marketing efforts for city hotels. This can help maximize revenue from this channel.
#
# **Negative Growth Implications:**
#
# GDS Contribution in Resort Hotels: The fact that GDS contributes zero to ADR in 'Resort Hotel' bookings may indicate a missed opportunity or a potential negative growth aspect. If 'Resort Hotel' wants to expand its reach and increase ADR, it might consider exploring partnerships with GDS providers or reevaluating its marketing strategy to attract GDS bookings.

# %% [markdown]
# #### Chart - 14
#
# ##### Q14. Relationship between ADR and total stay

# %%
#lets create scatter plot to see relationship between them.
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['total_stay'],y=df['adr'],hue=df['hotel'])
# Out:
# <Axes: xlabel='total_stay', ylabel='adr'>

# %%
#we can see that because of an outlier our scatterplot is looking messy let's remove that outlier and plot again
df.drop(df[df['adr'] > 5000].index, inplace = True)

# %%
#plot again
plt.figure(figsize=(15,10))
sns.scatterplot(x=df['total_stay'],y=df['adr'],hue=df['hotel'])
plt.title('Relation between ADR and total stay')
# Out:
# Text(0.5, 1.0, 'Relation between ADR and total stay')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# Scatterplot is an appropriate choice for your analysis because it effectively represents the relationship between two continuous variables, allows for the differentiation of data points based on a categorical variable, and provides the opportunity to address outliers for a more accurate visualization of the relationship. It's a common and valuable chart type for exploring and understanding data relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# *   As the number of total stay increasing adr is decreasing so we can say that more longer stay means better deal for guests.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer
#
# **Positive Impact:**
#
# Attracting Longer Stays: Hotels can use this insight to attract guests interested in longer stays by offering competitive pricing and special promotions. Longer stays can lead to increased occupancy rates, which is generally beneficial for a hotel's revenue.
#
# Guest Loyalty: Guests who enjoy better deals for extended stays may become loyal customers and choose the same hotel for future visits. This can result in repeat business, positive reviews, and recommendations to others.
#
# **Negative Growth Potential:**
#
# Profit Margins: Lowering ADRs for extended stays may reduce profit margins, especially if operating costs are not proportionately adjusted. Hotels need to carefully evaluate the trade-off between occupancy and profit to ensure financial sustainability.
#
# Competitive Position: Depending on the competitive landscape, other hotels in the area may or may not adopt similar pricing strategies. If neighboring hotels do not offer lower ADRs for longer stays, there's a risk of losing short-term guests to competitors

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
df.corr()
# Out:
# <ipython-input-51-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                        1.000000   0.184818           0.088037
# lead_time                          0.184818   1.000000           0.139133
# arrival_date_year                  0.088037   0.139133           1.000000
# arrival_date_week_number           0.001462   0.101145          -0.514235
# arrival_date_day_of_month          0.005308   0.009873          -0.010019
# stays_in_weekend_nights            0.060210   0.235141           0.005140
# stays_in_week_nights               0.082944   0.310126           0.003643
# adults                             0.081814   0.140494           0.038620
# ...

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-52-22f989dcb4db>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# Correlation heatmap is an effective way to visually explore and understand the relationships between variables in your dataset, making it a suitable choice for data analysis and presentation. It's particularly useful when working with numerical data to identify patterns, dependencies, and potential multicollinearity among variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# Total_stay and lead time have slight correlation it. This might means that customer plan reservation before their actual arrival.
#
# Adr(Average Daily Rate) is slightly correlated with total people, which makes sense as more number of people means more revenue.
#
# Previous booking not cancelled and repeated guest have high correlation as repeated guest are most likely to be who has not cancelled their previous bookings.
#
# We can also see that some columns have high correlation between them for example total people with adult and children it is because as those column are dervied from them by addition.

# %% [markdown]
# #### Chart - 16 - Pair Plot

# %%
# Pair Plot visualization code
variables_to_include = ["lead_time", "arrival_date_year", "arrival_date_week_number", "arrival_date_day_of_month","stays_in_weekend_nights",
                        "stays_in_week_nights", "is_repeated_guest","days_in_waiting_list", "total_stay", "total_people"]
sns.pairplot(df, kind="scatter", hue="is_canceled", markers=["o", "s"], palette="Set2", vars=variables_to_include, hue_order=[0, 1])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer
#
# Pairplots are a valuable tool for data exploration and visualization, allowing you to understand the relationships between variables and make informed decisions about data preprocessing and modeling. They are particularly effective when dealing with multivariate data or when you want to assess how variables interact with each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer
#
# * Here we can see that the relationship of one column with another one.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer
#
# **Based on the insights derived from the provided information, here are specific suggestions for the client to achieve their business objective of maximizing profitability and competitiveness in the hotel industry:**
#
# **Booking Preference and Trends:**
# Capitalize on the preference for City hotels by promoting their proximity to airports and railway stations. Highlight convenience in marketing materials.
# Continue to focus marketing efforts on years with high booking trends, such as 2016 and 2017. Create special promotions or packages for these years to attract more guests.
#
# **Meal Type Preference:**
# Since "BB" (Bed and Breakfast) is the most preferred meal type, consider offering attractive breakfast options and promotions to encourage bookings.
# Ensure that "SC" (Self Catering) and "HB" (Half Board) options are clearly
# defined and promoted to capture guests who prefer these meal types.
#
# **Correlation Analysis:**
# Leverage the correlation between "Total people" and ADR by offering deals or promotions for larger groups to increase revenue.
# Implement strategies to retain repeated guests, such as loyalty programs or personalized offers.
#
# **Length of Stay and ADR:**
# Offer discounts or special rates for longer stays to incentivize guests to extend their visits.
# Implement pricing strategies that take into account the inverse relationship between ADR and length of stay.
#
# **Booking Channel:**
# Invest in direct booking channels to reduce reliance on third-party agents and maximize revenue.
# Optimize GDS usage for City hotels where it contributes significantly to ADR.
#
# **Room Type Preference:**
# Ensure that the most preferred room type ("A") is well-promoted and readily available to guests.
# Consider offering special promotions or packages for less preferred room types ("L" and "P") to increase their appeal.
#
# **Customer Type:**
# Since "Transient" customers make up the majority, focus marketing efforts on this segment with personalized offers and promotions.
# Develop strategies to attract more "Group" customers and explore opportunities for partnerships with companies for "Contract" bookings.
#
# **Booking Distribution:**
# Offer incentives for bookings on days with lower distribution, such as the 31st day of the month, to balance booking distribution.
#
# **Booking Cancellation Rate:**
# Implement stricter cancellation policies and communicate them clearly during the booking process to reduce cancellations.
# Consider offering flexible booking options with a nominal fee for guests who are unsure about their plans.
#
# **Agent and ID Analysis:**
# Strengthen the relationship with Agent ID 9 and explore opportunities for exclusive partnerships.
# Analyze the booking behavior of other top-performing IDs (240, 94, 14, 7) to identify strategies for retaining their business.
#
# **Country Analysis:**
# Given the high number of guests from Portugal (PRT), consider tailoring marketing campaigns to attract more guests from the United Kingdom (GBR) and France (FRA).
# Explore partnerships with travel agencies and platforms in these countries to expand reach.
#
# **Data-Driven Decision-Making:**
# Invest in advanced data analytics tools and talent to continuously analyze and derive insights from data for more informed decision-making.
#
# **By implementing these strategies and aligning them with the insights gained from the data analysis, the client can work toward achieving their business objective of maximizing profitability and competitiveness in the hotel industry. Continuous monitoring and adaptation of strategies will be crucial for long-term success.**

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, the analysis of the provided information has revealed valuable insights for the hotel or hotel chain's business objective of maximizing profitability and competitiveness. These insights encompass various aspects of guest preferences, booking trends, correlations, and market dynamics.
#
# Key findings include the preference for City hotels, the importance of certain meal types, the impact of booking channels on ADR, and the significance of customer segmentation. Additionally, correlations between variables, such as length of stay and ADR, provide actionable information for pricing and revenue strategies.
#
# The analysis also highlights the importance of data-driven decision-making, the need for customer satisfaction efforts, and the potential for strengthening relationships with booking agents and specific customer segments.
#
# To achieve the business objective effectively, it is essential for the client to implement a range of strategies tailored to these insights, continually monitor performance metrics, and remain agile in responding to evolving market conditions and guest preferences. By doing so, the hotel or hotel chain can position itself for sustained profitability and competitiveness in the dynamic hospitality industry.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
